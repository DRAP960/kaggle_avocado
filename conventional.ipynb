# %%
import pandas as pd
import numpy as np
from datetime import datetime
from datetime import date
import calendar
import seaborn as sn
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv(r'C:\\Users\\dajir\\Downloads\\30292_38613_bundle_archive\\avocado.csv')

# %%
data.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
data.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# ...

# %% [markdown]
# There are no missing values in any of the columns

# %%
data.dtypes
# Out:
# Unnamed: 0        int64
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
data.shape
# Out:
# (18249, 14)

# %%
conventional=data[0:9126]

# %%
organic=data[9127:18249]

# %% [markdown]
# UNIVARIATE ANALYSIS FOR CONVENTIONAL AVOCADOS

# %%
sn.distplot(conventional['AveragePrice'])

# %% [markdown]
# The maximum avrage price for conventional avocado is 2.22 and minimum is 0.46
# The mean of avocado is 1.1580

# %%
sn.distplot(conventional['Total Volume'])

# %%
#UNIVARIATE ANALYSIS OF REGION
conventional['region'].value_counts()
# Out:
# PhoenixTucson          169
# GrandRapids            169
# BuffaloRochester       169
# StLouis                169
# Boston                 169
# HartfordSpringfield    169
# Indianapolis           169
# Houston                169
# Columbus               169
# Denver                 169
# SanDiego               169
# Orlando                169
# West                   169
# SouthCarolina          169
# Boise                  169
# Detroit                169
# Pittsburgh             169
# GreatLakes             169
# Albany                 169
# Seattle                169
# NewOrleansMobile       169
# LasVegas               169
# HarrisburgScranton     169
# NewYork                169
# LosAngeles             169
# California             169
# Portland               169
# BaltimoreWashington    169
# Jacksonville           169
# MiamiFtLauderdale      169
# RichmondNorfolk        169
# Charlotte              169
# SanFrancisco           169
# WestTexNewMexico       169
# ...

# %% [markdown]
# So,every region is having same number of entries

# %% [markdown]
# # BIVARIATE ANALYSIS OF CONVENTIONAL AVOCADOS
#
# The factors that effect the average price of the Avocado is 1)Total Bags (small,large and xl)
#                                                             2)Total Volume(4046U,4225U,4770U)
#                                                             3)Region
#                                                             4)year

# %%
#Bivariate analysis for Average price and Small Hass Avocados(i.e PLU4046)
conventional.plot.scatter("AveragePrice","4046")

# %%
conventional["AveragePrice"].corr(conventional["4046"])
# Out:
# -0.15185255805401962

# %% [markdown]
# Since, there slight negative correlation between Average price and the 4046 PLU avacados
# We can say that there is no correlation between Average Price and 4046U

# %%
#Bivariate analysis for Average price and Large Hass Avocados(i.e PLU4225)
conventional.plot.scatter("AveragePrice","4225")

# %%
conventional["AveragePrice"].corr(conventional["4225"])
# Out:
# -0.06426486976917964

# %%
#Bivariate analysis for Average price and Extra Large Hass Avocados(i.e PLU4770)
conventional.plot.scatter("AveragePrice","4770")

# %%
conventional["AveragePrice"].corr(conventional["4770"])
# Out:
# -0.11055460026420656

# %%
#Bivariate analysis for Average price and Total Volume
conventional.plot.scatter("AveragePrice","Total Volume")

# %%
conventional["AveragePrice"].corr(conventional["Total Volume"])
# Out:
# -0.10688544102114396

# %%
#Bivariate analysis for Average price and Small Bags
conventional.plot.scatter("AveragePrice","Small Bags")

# %%
conventional["AveragePrice"].corr(conventional["Small Bags"])
# Out:
# -0.08252777708290694

# %%
#Bivariate analysis for Average price and Large Bags
conventional.plot.scatter("AveragePrice","Large Bags")

# %%
conventional["AveragePrice"].corr(conventional["Large Bags"])
# Out:
# -0.1029747578046552

# %%
#Bivariate analysis for Average price and XLarge Bags
conventional.plot.scatter("AveragePrice","XLarge Bags")

# %%
conventional["AveragePrice"].corr(conventional["XLarge Bags"])
# Out:
# -0.020945748168744196

# %%
#Bivariate analysis for Average price and Total Bags
conventional.plot.scatter("AveragePrice","Total Bags")

# %%
conventional["AveragePrice"].corr(conventional["Total Bags"])
# Out:
# -0.08835822011083554

# %% [markdown]
# # Bivariate Analysis between region and Average Price

# %%
conventional.groupby('region')['AveragePrice'].mean().plot.bar()

# %%
conventional.groupby('region')['AveragePrice'].mean().max()
# Out:
# 1.4080473372781062

# %%
conventional.groupby('region')['AveragePrice'].mean().min()
# Out:
# 0.7282248520710065

# %%
conventional.groupby('region')['AveragePrice'].mean().mean()
# Out:
# 1.1580396668858208

# %% [markdown]
# # Bivariate Analysis of Average Price and year

# %%
conventional.groupby('year')['AveragePrice'].mean().value_counts()
# Out:
# 1.077963    1
# 1.127886    1
# 1.105595    1
# 1.294888    1
# Name: AveragePrice, dtype: int64

# %%
conventional.groupby('year')['AveragePrice'].mean().plot.bar()

# %% [markdown]
# # Bivariate analysis total volumes and year

# %%
conventional.groupby('year')['Total Volume'].mean().plot.bar()

# %%
conventional.groupby('year')['4046'].mean().plot.bar()

# %%
conventional.groupby('year')['4225'].mean().plot.bar()

# %%
conventional.groupby('year')['4770'].mean().plot.bar()

# %% [markdown]
# # Bivariate analysis of total bags and Year

# %%
conventional.groupby('year')['Total Bags'].mean().plot.bar()

# %%
conventional.groupby('year')['Small Bags'].mean().plot.bar()

# %%
conventional.groupby('year')['Large Bags'].mean().plot.bar()

# %%
conventional.groupby('year')['XLarge Bags'].mean().plot.bar()

# %% [markdown]
# # Using Linear Regression

# %%
#Making Train and test data sets
conv_train=conventional[0:7999]
conv_test=conventional[8000:]

# %%
X=boston.data
Y=boston.target

# %%
#Indepedent Variable
x_train=conv_train.drop(['AveragePrice','year','region'],axis=1)

# %%
#Dependent Variable
y_train=conv_train['Total Volume']

# %%
#independent Variable in test data set
x_test=conv_test.drop(['AveragePrice','year','region'],axis=1)

# %%
#Dependent Variable in test data set
y_test=conv_test['Total Volume']

# %%
from sklearn.datasets import load_boston
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
lin_reg=LinearRegression()
boston=load_boston()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.33, shuffle= True)

# %%
lin_reg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
predicted=lin_reg.score(X_test, y_test )
predicted
# Out:
# 0.6821417759520614
